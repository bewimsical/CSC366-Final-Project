# %%
# Get all JSON files in the folder-change the folder to merge different groups of files
file_paths = glob.glob("allBestBuy/*.json")

# Load all product lists
all_products = []

for path in file_paths:
    with open(path, "r") as file:
        data = json.load(file)
        # assuming each file contains a list of products
        all_products.extend(data)

# Save the combined list into one JSON file
with open("all-bb-data.json", "w") as file:
    json.dump(all_products, file, indent=4)

print(f"Merged {len(file_paths)} files, total {len(all_products)} products.")
# Out:
# Merged 3 files, total 2227 products.

# %%
import json
import pandas as pd
import glob

# %%
with open("all-laptop-data.json", "r") as f:
    data = json.load(f)

for chore in data:
    chore["class"] = None
    chore["class"] = "phone"

with open("updated-phone-data.json", "w") as file:
    json.dump(data, file, indent=4)

# %%
#once all files are combined, turn them into a dataframe
with open(f"all-bb-data.json", 'r') as f:
        data = json.load(f)
df = pd.DataFrame(data)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2227 entries, 0 to 2226
# Columns: 180 entries, sku to mountBracketVesaPattern
# dtypes: bool(14), float64(13), int64(1), object(152)
# memory usage: 2.9+ MB

# %%
#filter products to get relevent columns 
# df = df[["sku","name", "customerReviewAverage", "customerReviewCount", "customerTopRated", "manufacturer", "class", "condition", "modelNumber"]]
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2227 entries, 0 to 2226
# Columns: 180 entries, sku to mountBracketVesaPattern
# dtypes: bool(14), float64(13), int64(1), object(152)
# memory usage: 2.9+ MB

# %%
df.to_csv("best-buy-products-updated.csv", index=False)

# %%
#check to make sure CSV is accurate
df=pd.read_csv("best-buy-products.csv")
df = df[["sku","name", "customerReviewAverage", "customerReviewCount", "customerTopRated", "manufacturer", "class", "condition", "modelNumber"]]
df
# Out:
#           sku                                               name  \
# 0     6636904  Lenovo - T14 G2 14" Refurbished Laptop - Intel...
# 1     6636905  HP - EliteBook 840 G7 14" Refurbished Laptop -...
# 2     6636906  HP - EliteBook 850 G7 15.6" Refurbished Laptop...
# 3     6636931  HP - OmniBook X - Copilot+ PC - 17.3" Full HD ...
# 4     6637409  HP - 15.6" Laptop - Intel Core i3 - 8GB Memory...
# ...       ...                                                ...
# 1219  6534601  Apple - MacBook Air 15" Laptop - M2 chip Built...
# 1220  6534603  Apple - MacBook Air 15" Laptop - M2 chip Built...
# 1221  6534612  Apple - MacBook Pro 16" Laptop - M3 Max chip B...
# 1222  6534614  Apple - MacBook Pro 16" Laptop - M3 Max chip B...
# 1223  6534615  Apple - MacBook Pro 14" Laptop - M3 Pro chip B...
#
#       customerReviewAverage  customerReviewCount customerTopRated  \
# 0                       3.0                  1.0            False
# ...
