# %%
import pandas as pd
import numpy as np

df=pd.read_csv("best-buy-products-updated.csv")
df = df[["sku","name", "customerReviewAverage", "customerReviewCount", "customerTopRated", "manufacturer", "class", "condition", "modelNumber",  "salePrice"]]

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1224 entries, 0 to 1223
# Data columns (total 10 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   sku                    1224 non-null   int64
#  1   name                   1224 non-null   object
#  2   customerReviewAverage  846 non-null    float64
#  3   customerReviewCount    846 non-null    float64
#  4   customerTopRated       846 non-null    object
#  5   manufacturer           1223 non-null   object
#  6   class                  1224 non-null   object
#  7   condition              1224 non-null   object
#  8   modelNumber            1223 non-null   object
#  9   salePrice              1224 non-null   float64
# dtypes: float64(3), int64(1), object(6)
# memory usage: 95.8+ KB

# %%
import json

with open(f"top-10/top-10-desktop-data.json", 'r') as f:
    data = json.load(f)
desktop = pd.DataFrame(data)

desktop.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 8 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   sku              10 non-null     object
#  1   customerReviews  10 non-null     object
#  2   descriptions     10 non-null     object
#  3   images           10 non-null     object
#  4   names            10 non-null     object
#  5   prices           10 non-null     object
#  6   links            10 non-null     object
#  7   rank             10 non-null     int64
# dtypes: int64(1), object(7)
# memory usage: 768.0+ bytes

# %%
import json

with open(f"top-10/top-10-laptop-data.json", 'r') as f:
    data = json.load(f)
laptop = pd.DataFrame(data)

laptop.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 8 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   sku              10 non-null     object
#  1   customerReviews  10 non-null     object
#  2   descriptions     10 non-null     object
#  3   images           10 non-null     object
#  4   names            10 non-null     object
#  5   prices           10 non-null     object
#  6   links            10 non-null     object
#  7   rank             10 non-null     int64
# dtypes: int64(1), object(7)
# memory usage: 768.0+ bytes

# %%
import json

with open(f"top-10/top-10-phone-data.json", 'r') as f:
    data = json.load(f)
phone = pd.DataFrame(data)

phone.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 8 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   sku              10 non-null     object
#  1   customerReviews  10 non-null     object
#  2   descriptions     10 non-null     object
#  3   images           10 non-null     object
#  4   names            10 non-null     object
#  5   prices           10 non-null     object
#  6   links            10 non-null     object
#  7   rank             10 non-null     int64
# dtypes: int64(1), object(7)
# memory usage: 768.0+ bytes

# %%
df["bestseller"] = df["sku"].astype(str).isin(laptop["sku"].astype(str))
df["sku"] = df["sku"].astype(str)
laptop["sku"] = laptop["sku"].astype(str)

df = df.merge(laptop[["sku", "rank"]], on="sku", how="left")

print(df["bestseller"].value_counts())
print(df["rank"].value_counts())
# Out:
# bestseller
# False    1214
# True       10
# Name: count, dtype: int64
# rank
# 2.0     1
# 4.0     1
# 6.0     1
# 5.0     1
# 3.0     1
# 10.0    1
# 8.0     1
# 7.0     1
# 1.0     1
# 9.0     1
# Name: count, dtype: int64
